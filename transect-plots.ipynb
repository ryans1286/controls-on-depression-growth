# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import seaborn as sns
import pickle
from landlab import RasterModelGrid, imshow_grid
from matplotlib import cbook
from matplotlib import cm
from matplotlib.colors import LightSource

# %%
directory = 'output-1a-transects'

# %%
ice1 = pd.read_csv(directory + '/sim_1_s_trans.csv')
topo1 = pd.read_csv(directory + '/sim_1_z_trans.csv')
ice2 = pd.read_csv(directory + '/sim_2_s_trans.csv')
topo2 = pd.read_csv(directory + '/sim_2_z_trans.csv')
ice3 = pd.read_csv(directory + '/sim_3_s_trans.csv')
topo3 = pd.read_csv(directory + '/sim_3_z_trans.csv')
ice4 = pd.read_csv(directory + '/sim_4_s_trans.csv')
topo4 = pd.read_csv(directory + '/sim_4_z_trans.csv')
ice5 = pd.read_csv(directory + '/sim_5_s_trans.csv')
topo5 = pd.read_csv(directory + '/sim_5_z_trans.csv')
ice6= pd.read_csv(directory + '/sim_6_s_trans.csv')
topo6 = pd.read_csv(directory + '/sim_6_z_trans.csv')
ice7 = pd.read_csv(directory + '/sim_7_s_trans.csv')
topo7 = pd.read_csv(directory + '/sim_7_z_trans.csv')
ice8 = pd.read_csv(directory + '/sim_8_s_trans.csv')
topo8 = pd.read_csv(directory + '/sim_8_z_trans.csv')
ice9= pd.read_csv(directory + '/sim_9_s_trans.csv')
topo9 = pd.read_csv(directory + '/sim_9_z_trans.csv')

# %%
times = [1, 10, 20, 30, 40, 49]
left = 27
right = 73


color1 = cm.cool_r(np.linspace(0, 1, len(times)+1))
color2 = cm.copper_r(np.linspace(0, 1, len(times)+1))
color3 = cm.winter_r(np.linspace(0, 1, len(times)+1))

linestyle = ['dotted', 'dashed', 'solid']
fig, ax = plt.subplots(1,3, sharey = True, figsize = (9,4))
c = 0
for t in times:
    print(t, c)
    t = str(t)
    ax[2].plot(topo1['x'][left:right]-50, topo1[t][left:right]-topo1['1'][left], c = color1[c], linestyle = linestyle[0], linewidth = 2)
    ax[2].plot(topo2['x'][left:right]-50, topo2[t][left:right]-topo2['1'][left], c = color1[c], linestyle = linestyle[1], linewidth = 2)
    ax[2].plot(topo3['x'][left:right]-50, topo3[t][left:right]-topo3['1'][left], c = color1[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[1].plot(topo4['x'][left:right]-50, topo4[t][left:right]-topo4['1'][left], c = color2[c], linestyle = linestyle[0], linewidth = 2)
    ax[1].plot(topo5['x'][left:right]-50, topo5[t][left:right]-topo5['1'][left], c = color2[c], linestyle = linestyle[1], linewidth = 2)
    ax[1].plot(topo6['x'][left:right]-50, topo6[t][left:right]-topo6['1'][left], c = color2[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[0].plot(topo7['x'][left:right]-50, topo7[t][left:right]-topo7['1'][left], c = color3[c], linestyle = linestyle[0], linewidth = 2)
    ax[0].plot(topo8['x'][left:right]-50, topo8[t][left:right]-topo8['1'][left], c = color3[c], linestyle = linestyle[1], linewidth = 2)
    ax[0].plot(topo9['x'][left:right]-50, topo9[t][left:right]-topo9['1'][left], c = color3[c], linestyle = linestyle[2], linewidth = 2)
    c += 1

#plt.axis('equal')

ax[0].set_xlabel('Position (m)', fontsize = 12)
ax[1].set_xlabel('Position (m)', fontsize = 12)
ax[2].set_xlabel('Position (m)', fontsize = 12)
ax[0].set_ylabel('$\\Delta z$ (m)', fontsize = 12)

ax[0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)

ax[0].annotate('(a)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[1].annotate('(b)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[2].annotate('(c)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)

plt.legend(['$\\kappa = 0.1$ m$^{-1}$', '$\\kappa = 0.15$ m$^{-1}$', '$\\kappa = 0.2$ m$^{-1}$'], bbox_to_anchor = (0.38, -0.15), ncol = 3)
ax = plt.gca()
leg = ax.get_legend()
leg.legend_handles[0].set_color('gray')
leg.legend_handles[1].set_color('gray')
leg.legend_handles[2].set_color('gray')

#plt.savefig('elevation-transects.png', dpi = 300, bbox_inches = 'tight')
plt.show()
# Out:
# 1 0
# 10 1
# 20 2
# 30 3
# 40 4
# 49 5

# %%
times = [1, 10, 20, 30, 40, 49]
left = 27
right = 73

color1 = cm.cool_r(np.linspace(0, 1, len(times)+1))
color2 = cm.copper_r(np.linspace(0, 1, len(times)+1))
color3 = cm.winter_r(np.linspace(0, 1, len(times)+1))
linestyle = ['dotted', 'dashed', 'solid']
fig, ax = plt.subplots(1,3, sharey = True, figsize = (9, 4))
c = 0
for t in times:
    print(t, c)
    t = str(t)
    ax[2].plot(topo1['x'][left:right]-50, ice1[t][left:right]-ice1['1'][left], c = color1[c], linestyle = linestyle[0], linewidth = 2)
    ax[2].plot(topo2['x'][left:right]-50, ice2[t][left:right]-ice2['1'][left], c = color1[c], linestyle = linestyle[1], linewidth = 2)
    ax[2].plot(topo3['x'][left:right]-50, ice3[t][left:right]-ice3['1'][left], c = color1[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[1].plot(topo4['x'][left:right]-50, ice4[t][left:right]-ice4['1'][left], c = color2[c], linestyle = linestyle[0], linewidth = 2)
    ax[1].plot(topo5['x'][left:right]-50, ice5[t][left:right]-ice5['1'][left], c = color2[c], linestyle = linestyle[1], linewidth = 2)
    ax[1].plot(topo6['x'][left:right]-50, ice6[t][left:right]-ice6['1'][left], c = color2[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[0].plot(topo7['x'][left:right]-50, ice7[t][left:right]-ice4['1'][left], c = color3[c], linestyle = linestyle[0], linewidth = 2)
    ax[0].plot(topo8['x'][left:right]-50, ice8[t][left:right]-ice5['1'][left], c = color3[c], linestyle = linestyle[1], linewidth = 2)
    ax[0].plot(topo9['x'][left:right]-50, ice9[t][left:right]-ice6['1'][left], c = color3[c], linestyle = linestyle[2], linewidth = 2)
    c += 1

#plt.axis('equal')

ax[0].set_xlabel('Position (m)', fontsize = 12)
ax[1].set_xlabel('Position (m)', fontsize = 12)
ax[2].set_xlabel('Position (m)', fontsize = 12)
ax[0].set_ylabel('$\\Delta s$ (m)', fontsize = 12)

ax[0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)

ax[0].annotate('(a)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[1].annotate('(b)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[2].annotate('(c)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)

plt.legend(['$\\kappa = 0.1$ m$^{-1}$', '$\\kappa = 0.15$ m$^{-1}$', '$\\kappa = 0.2$ m$^{-1}$'], bbox_to_anchor = (0.38, -0.15), ncol = 3)
ax = plt.gca()
leg = ax.get_legend()
leg.legend_handles[0].set_color('gray')
leg.legend_handles[1].set_color('gray')
leg.legend_handles[2].set_color('gray')

#plt.savefig('ice-transects.png', dpi = 300, bbox_inches = 'tight')
plt.show()
# Out:
# 1 0
# 10 1
# 20 2
# 30 3
# 40 4
# 49 5

# %%
times = [1, 25, 49]
left = 27
right = 73

color1 = cm.cool_r(np.linspace(0, 1, len(times)+1))
color2 = cm.copper_r(np.linspace(0, 1, len(times)+1))
color3 = cm.winter_r(np.linspace(0, 1, len(times)+1))
linestyle = ['solid', 'solid', 'solid']
fig, ax = plt.subplots(3,3, sharey = True, figsize = (9,9))
c = 0
for t in times:
    print(t, c)
    t = str(t)
    ax[0,2].plot(topo1['x'][left:right]-50, topo1[t][left:right]-ice1[t][left:right], c = color1[c], linestyle = linestyle[0], linewidth = 2)
    ax[1,2].plot(topo2['x'][left:right]-50, topo2[t][left:right]-ice2[t][left:right], c = color1[c], linestyle = linestyle[1], linewidth = 2)
    ax[2,2].plot(topo3['x'][left:right]-50, topo3[t][left:right]-ice3[t][left:right], c = color1[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[0,1].plot(topo4['x'][left:right]-50, topo4[t][left:right]-ice4[t][left:right], c = color2[c], linestyle = linestyle[0], linewidth = 2)
    ax[1,1].plot(topo5['x'][left:right]-50, topo5[t][left:right]-ice5[t][left:right], c = color2[c], linestyle = linestyle[1], linewidth = 2)
    ax[2,1].plot(topo6['x'][left:right]-50, topo6[t][left:right]-ice6[t][left:right], c = color2[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[0,0].plot(topo7['x'][left:right]-50, topo7[t][left:right]-ice7[t][left:right], c = color3[c], linestyle = linestyle[0], linewidth = 2)
    ax[1,0].plot(topo8['x'][left:right]-50, topo8[t][left:right]-ice8[t][left:right], c = color3[c], linestyle = linestyle[1], linewidth = 2)
    ax[2,0].plot(topo9['x'][left:right]-50, topo9[t][left:right]-ice9[t][left:right], c = color3[c], linestyle = linestyle[2], linewidth = 2)
    c += 1

#plt.axis('equal')

ax[2,0].set_xlabel('Position (m)', fontsize = 12)
ax[2,1].set_xlabel('Position (m)', fontsize = 12)
ax[2,2].set_xlabel('Position (m)', fontsize = 12)

ax[0,0].set_ylabel('$h$ (m)', fontsize = 12)
ax[1,0].set_ylabel('$h$ (m)', fontsize = 12)
ax[2,0].set_ylabel('$h$ (m)', fontsize = 12)

ax[0,0].annotate('$\\kappa = 0.1$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[1,0].annotate('$\\kappa = 0.15$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[2,0].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[0,0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[1,0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[2,0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)

ax[0,1].annotate('$\\kappa = 0.1$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[1,1].annotate('$\\kappa = 0.15$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[2,1].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[0,1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[1,1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[2,1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)

ax[0,2].annotate('$\\kappa = 0.1$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[1,2].annotate('$\\kappa = 0.15$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[2,2].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[0,2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[1,2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[2,2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)

ax[0,0].annotate('(a)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[0,1].annotate('(b)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[0,2].annotate('(c)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)

ax[1,0].annotate('(d)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[1,1].annotate('(e)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[1,2].annotate('(f)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)

ax[2,0].annotate('(g)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[2,1].annotate('(h)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)
ax[2,2].annotate('(i)', xy = (-.1, 1.05), xycoords = 'axes fraction', fontsize = 12)


#plt.legend(['$\\kappa = 0.1$ m$^{-1}$', '$\\kappa = 0.15$ m$^{-1}$', '$\\kappa = 0.2$ m$^{-1}$'], bbox_to_anchor = (0.88, 1.12), ncol = 3)
#ax = plt.gca()
#leg = ax.get_legend()
#leg.legend_handles[0].set_color('gray')
#leg.legend_handles[1].set_color('gray')
#leg.legend_handles[2].set_color('gray')

#plt.savefig('debris-transects.png', dpi = 300, bbox_inches = 'tight')
plt.show()
# Out:
# 1 0
# 25 1
# 49 2

# %%
#Makes cross section animations. Set end of range to number of years
for t in range(1, 1):
    t = str(t)
    fig, ax = plt.subplots(1, 3, sharey = True, figsize = (12, 3))
    ax[0].plot(topo9['x'][left:right]-50, topo9[t][left:right]-topo9[t][left:right].max(), linewidth = 1, color = 'grey')
    ax[0].plot(topo9['x'][left:right]-50, ice9[t][left:right]-topo9[t][left:right].max(), linewidth = 1, color = 'lightsteelblue')
    ax[0].fill_between(topo9['x'][left:right]-50, ice9[t][left:right]-topo9[t][left:right].max(), topo9[t][left:right]-topo9[t][left:right].max(), color = 'grey')
    ax[0].fill_between(topo9['x'][left:right]-50, -np.ones(len(topo9['x'][left:right]))*4.25, ice9[t][left:right]-topo9[t][left:right].max(), color = 'lightsteelblue')
    
    ax[1].plot(topo6['x'][left:right]-50, topo6[t][left:right]-topo6[t][left:right].max(), linewidth = 1, color = 'grey')
    ax[1].plot(topo6['x'][left:right]-50, ice6[t][left:right]-topo6[t][left:right].max(), linewidth = 1, color = 'lightsteelblue')
    ax[1].fill_between(topo6['x'][left:right]-50, ice6[t][left:right]-topo6[t][left:right].max(), topo6[t][left:right]-topo6[t][left:right].max(), color = 'grey')
    ax[1].fill_between(topo6['x'][left:right]-50, -np.ones(len(topo6['x'][left:right]))*4.25, ice6[t][left:right]-topo6[t][left:right].max(), color = 'lightsteelblue')
    
    ax[2].plot(topo3['x'][left:right]-50, topo3[t][left:right]-topo3[t][left:right].max(), linewidth = 1, color = 'grey')
    ax[2].plot(topo3['x'][left:right]-50, ice3[t][left:right]-topo3[t][left:right].max(), linewidth = 1, color = 'lightsteelblue')
    ax[2].fill_between(topo3['x'][left:right]-50, ice3[t][left:right]-topo3[t][left:right].max(), topo3[t][left:right]-topo3[t][left:right].max(), color = 'grey')
    ax[2].fill_between(topo3['x'][left:right]-50, -np.ones(len(topo3['x'][left:right]))*4.25, ice3[t][left:right]-topo3[t][left:right].max(), color = 'lightsteelblue')
    
    ax[0].set_ylabel('Relief (m)', fontsize = 12)
    ax[0].set_xlabel('Position (m)', fontsize = 12)
    ax[1].set_xlabel('Position (m)', fontsize = 12)
    ax[2].set_xlabel('Position (m)', fontsize = 12)
    
    ax[0].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.65, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[1].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.65, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[2].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.65, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.05, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.05, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.05), xycoords = 'axes fraction', fontsize = 9)
    
    #plt.savefig('transect-animations/varying-R-' + t + '.png', dpi = 300, bbox_inches = 'tight')
    plt.show()

# %%
#same as above

for t in range(1, 1):
    t = str(t)
    fig, ax = plt.subplots(1, 3, sharey = True, figsize = (12, 3))
    ax[0].plot(topo1['x'][left:right]-50, topo1[t][left:right]-topo1[t][left:right].max(), linewidth = 1, color = 'grey')
    ax[0].plot(topo1['x'][left:right]-50, ice1[t][left:right]-topo1[t][left:right].max(), linewidth = 1, color = 'lightsteelblue')
    ax[0].fill_between(topo1['x'][left:right]-50, ice1[t][left:right]-topo1[t][left:right].max(), topo1[t][left:right]-topo1[t][left:right].max(), color = 'grey')
    ax[0].fill_between(topo1['x'][left:right]-50, -np.ones(len(topo1['x'][left:right]))*4.25, ice1[t][left:right]-topo1[t][left:right].max(), color = 'lightsteelblue')
    
    ax[1].plot(topo2['x'][left:right]-50, topo2[t][left:right]-topo2[t][left:right].max(), linewidth = 1, color = 'grey')
    ax[1].plot(topo2['x'][left:right]-50, ice2[t][left:right]-topo2[t][left:right].max(), linewidth = 1, color = 'lightsteelblue')
    ax[1].fill_between(topo2['x'][left:right]-50, ice2[t][left:right]-topo2[t][left:right].max(), topo2[t][left:right]-topo2[t][left:right].max(), color = 'grey')
    ax[1].fill_between(topo2['x'][left:right]-50, -np.ones(len(topo2['x'][left:right]))*4.25, ice2[t][left:right]-topo2[t][left:right].max(), color = 'lightsteelblue')
    
    ax[2].plot(topo3['x'][left:right]-50, topo3[t][left:right]-topo3[t][left:right].max(), linewidth = 1, color = 'grey')
    ax[2].plot(topo3['x'][left:right]-50, ice3[t][left:right]-topo3[t][left:right].max(), linewidth = 1, color = 'lightsteelblue')
    ax[2].fill_between(topo3['x'][left:right]-50, ice3[t][left:right]-topo3[t][left:right].max(), topo3[t][left:right]-topo3[t][left:right].max(), color = 'grey')
    ax[2].fill_between(topo3['x'][left:right]-50, -np.ones(len(topo3['x'][left:right]))*4.25, ice3[t][left:right]-topo3[t][left:right].max(), color = 'lightsteelblue')
    
    ax[0].set_ylabel('Relief (m)', fontsize = 12)
    ax[0].set_xlabel('Position (m)', fontsize = 12)
    ax[1].set_xlabel('Position (m)', fontsize = 12)
    ax[2].set_xlabel('Position (m)', fontsize = 12)
    
    ax[0].annotate('$\\kappa = 0.1$ m$^{-1}$', xy = (0.65, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[1].annotate('$\\kappa = 0.15$ m$^{-1}$', xy = (0.65, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[2].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.65, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[0].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[1].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.05), xycoords = 'axes fraction', fontsize = 9)
    ax[2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.05), xycoords = 'axes fraction', fontsize = 9)
    plt.savefig('transect-animations/varying-K-' + t + '.png', dpi = 300, bbox_inches = 'tight')
    plt.show()

# %%
path = 'output-1a-transects'

with open(path + '/sim_3_s_time=49.pkl', 'rb') as f:
    s = pickle.load(f)

# %%
mg = RasterModelGrid((101, 101), xy_spacing=1)
s_trans = mg.node_vector_to_raster(s)[:,101//2]

# %%
plt.plot(np.arange(0,101,1), s_trans)

# %%
years = [1, 10, 20, 30, 40, 49]

for y in years:
    with open(path + '/sim_3_s_time=' + str(y) + '.pkl', 'rb') as f:
        s = pickle.load(f)
    mg = RasterModelGrid((101, 101), xy_spacing=1)
    s_trans = mg.node_vector_to_raster(s)[:,101//2]
    plt.plot(np.arange(0,101,1)[30:100]-50, (s_trans)[30:100])
plt.show()

# %%
years = [1, 10, 20, 30, 40, 49]

color1 = cm.cool_r(np.linspace(0, 1, 7))
color2 = cm.copper_r(np.linspace(0, 1, 7))
color3 = cm.winter_r(np.linspace(0, 1, 7))
linestyle = ['dotted', 'dashed', 'solid']
fig, ax = plt.subplots(1,3, sharey = True, figsize = (9, 4))
c = 0
for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+1) + '_s_time=' + str(y) + '.pkl', 'rb') as f:
            s = pickle.load(f)
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        s_trans = mg.node_vector_to_raster(s)[:,101//2]

        ax[2].plot(np.arange(0,101,1)[30:100]-50, (s_trans)[30:100]-100, c = color1[count], linestyle = linestyle[c], linewidth = 2)
        count += 1
        
for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+4) + '_s_time=' + str(y) + '.pkl', 'rb') as f:
            s = pickle.load(f)
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        s_trans = mg.node_vector_to_raster(s)[:,101//2]

        ax[1].plot(np.arange(0,101,1)[30:100]-50, (s_trans)[30:100]-100, c = color2[count], linestyle = linestyle[c], linewidth = 2)
        count += 1

handles = [0,0,0]
for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+7) + '_s_time=' + str(y) + '.pkl', 'rb') as f:
            s = pickle.load(f)
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        s_trans = mg.node_vector_to_raster(s)[:,101//2]

        handles[c], = ax[0].plot(np.arange(0,101,1)[30:100]-50, (s_trans)[30:100]-100, c = color3[count], linestyle = linestyle[c], linewidth = 2)
        count += 1

#plt.axis('equal')

ax[0].set_xlabel('Position (m)', fontsize = 12)
ax[1].set_xlabel('Position (m)', fontsize = 12)
ax[2].set_xlabel('Position (m)', fontsize = 12)
ax[0].set_ylabel('$\\Delta s$ (m)', fontsize = 12)

ax[0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)

ax[0].annotate('(a)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[1].annotate('(b)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[2].annotate('(c)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)

plt.legend(handles = handles, labels = ['$\\kappa = 0.1$ m$^{-1}$', '$\\kappa = 0.15$ m$^{-1}$', '$\\kappa = 0.2$ m$^{-1}$'], bbox_to_anchor = (0.38, -0.15), ncol = 3)
ax = plt.gca()
leg = ax.get_legend()
leg.legend_handles[0].set_color('gray')
leg.legend_handles[1].set_color('gray')
leg.legend_handles[2].set_color('gray')

#plt.suptitle('Transects Parallel to Glacier Slope')
plt.savefig('ice-transects-down.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
years = [1, 10, 20, 30, 40, 49]

color1 = cm.cool_r(np.linspace(0, 1, 7))
color2 = cm.copper_r(np.linspace(0, 1, 7))
color3 = cm.winter_r(np.linspace(0, 1, 7))
linestyle = ['dotted', 'dashed', 'solid']
fig, ax = plt.subplots(1,3, sharey = True, figsize = (9, 4))
c = 0
for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+1) + '_z_time=' + str(y) + '.pkl', 'rb') as f:
            z = pickle.load(f)
            
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        z_trans = mg.node_vector_to_raster(z)[:,101//2]

        ax[2].plot(np.arange(0,101,1)[30:100]-50, (z_trans)[30:100]-100, c = color1[count], linestyle = linestyle[c], linewidth = 2)
        count += 1
        
for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+4) + '_z_time=' + str(y) + '.pkl', 'rb') as f:
            z = pickle.load(f)
            
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        z_trans = mg.node_vector_to_raster(z)[:,101//2]

        ax[1].plot(np.arange(0,101,1)[30:100]-50, (z_trans)[30:100]-100, c = color2[count], linestyle = linestyle[c], linewidth = 2)
        count += 1
handles = [0,0,0]    
for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+7) + '_z_time=' + str(y) + '.pkl', 'rb') as f:
            z = pickle.load(f)
            
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        z_trans = mg.node_vector_to_raster(z)[:,101//2]

        handles[c], = ax[0].plot(np.arange(0,101,1)[30:100]-50, (z_trans)[30:100]-100, c = color3[count], linestyle = linestyle[c], linewidth = 2)
        count += 1

#plt.axis('equal')

ax[0].set_xlabel('Position (m)', fontsize = 12)
ax[1].set_xlabel('Position (m)', fontsize = 12)
ax[2].set_xlabel('Position (m)', fontsize = 12)
ax[0].set_ylabel('$\\Delta z$ (m)', fontsize = 12)

ax[0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)
ax[2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.05, 0.015), xycoords = 'axes fraction', fontsize = 9)

ax[0].annotate('(a)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[1].annotate('(b)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[2].annotate('(c)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)

plt.legend(handles = handles, labels = ['$\\kappa = 0.1$ m$^{-1}$', '$\\kappa = 0.15$ m$^{-1}$', '$\\kappa = 0.2$ m$^{-1}$'], bbox_to_anchor = (0.38, -0.15), ncol = 3)
ax = plt.gca()
leg = ax.get_legend()
leg.legend_handles[0].set_color('gray')
leg.legend_handles[1].set_color('gray')
leg.legend_handles[2].set_color('gray')

#plt.suptitle('Transects Parallel to Glacier Slope')
plt.savefig('elev-transects-down.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
years = [1, 25, 49]

color1 = cm.cool_r(np.linspace(0, 1, 4))
color2 = cm.copper_r(np.linspace(0, 1, 4))
color3 = cm.winter_r(np.linspace(0, 1, 4))
linestyle = ['solid', 'solid', 'solid']
fig, ax = plt.subplots(3,3, sharey = True, figsize = (9,9))
c = 0

for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+1) + '_z_time=' + str(y) + '.pkl', 'rb') as f:
            z = pickle.load(f)
        with open(path + '/sim_' + str(c+1) + '_s_time=' + str(y) + '.pkl', 'rb') as f:
            s = pickle.load(f)
            
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        z_trans = mg.node_vector_to_raster(z)[:,101//2]
        s_trans = mg.node_vector_to_raster(s)[:,101//2]

        ax[c,2].plot(np.arange(0,101,1)[30:100]-50, (z_trans)[30:100]-(s_trans)[30:100], c = color1[count], linestyle = linestyle[c], linewidth = 2)
        count += 1
        
for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+4) + '_z_time=' + str(y) + '.pkl', 'rb') as f:
            z = pickle.load(f)
        with open(path + '/sim_' + str(c+4) + '_s_time=' + str(y) + '.pkl', 'rb') as f:
            s = pickle.load(f)
            
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        z_trans = mg.node_vector_to_raster(z)[:,101//2]
        s_trans = mg.node_vector_to_raster(s)[:,101//2]

        ax[c,1].plot(np.arange(0,101,1)[30:100]-50, (z_trans)[30:100]-(s_trans)[30:100], c = color2[count], linestyle = linestyle[c], linewidth = 2)
        count += 1

for c in range(3):
    count = 0
    for y in years:

        with open(path + '/sim_' + str(c+7) + '_z_time=' + str(y) + '.pkl', 'rb') as f:
            z = pickle.load(f)
        with open(path + '/sim_' + str(c+7) + '_s_time=' + str(y) + '.pkl', 'rb') as f:
            s = pickle.load(f)
            
        mg = RasterModelGrid((101, 101), xy_spacing=1)
        z_trans = mg.node_vector_to_raster(z)[:,101//2]
        s_trans = mg.node_vector_to_raster(s)[:,101//2]

        ax[c,0].plot(np.arange(0,101,1)[30:100]-50, (z_trans)[30:100]-(s_trans)[30:100], c = color3[count], linestyle = linestyle[c], linewidth = 2)
        count += 1

"""
for t in times:
    print(t, c)
    t = str(t)
    ax[0,2].plot(topo1['x'][left:right]-50, topo1[t][left:right]-ice1[t][left:right], c = color1[c], linestyle = linestyle[0], linewidth = 2)
    ax[1,2].plot(topo2['x'][left:right]-50, topo2[t][left:right]-ice2[t][left:right], c = color1[c], linestyle = linestyle[1], linewidth = 2)
    ax[2,2].plot(topo3['x'][left:right]-50, topo3[t][left:right]-ice3[t][left:right], c = color1[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[0,1].plot(topo4['x'][left:right]-50, topo4[t][left:right]-ice4[t][left:right], c = color2[c], linestyle = linestyle[0], linewidth = 2)
    ax[1,1].plot(topo5['x'][left:right]-50, topo5[t][left:right]-ice5[t][left:right], c = color2[c], linestyle = linestyle[1], linewidth = 2)
    ax[2,1].plot(topo6['x'][left:right]-50, topo6[t][left:right]-ice6[t][left:right], c = color2[c], linestyle = linestyle[2], linewidth = 2)
    
    ax[0,0].plot(topo7['x'][left:right]-50, topo7[t][left:right]-ice7[t][left:right], c = color3[c], linestyle = linestyle[0], linewidth = 2)
    ax[1,0].plot(topo8['x'][left:right]-50, topo8[t][left:right]-ice8[t][left:right], c = color3[c], linestyle = linestyle[1], linewidth = 2)
    ax[2,0].plot(topo9['x'][left:right]-50, topo9[t][left:right]-ice9[t][left:right], c = color3[c], linestyle = linestyle[2], linewidth = 2)
    c += 1
"""
#plt.axis('equal')

ax[2,0].set_xlabel('Position (m)', fontsize = 12)
ax[2,1].set_xlabel('Position (m)', fontsize = 12)
ax[2,2].set_xlabel('Position (m)', fontsize = 12)

ax[0,0].set_ylabel('$h$ (m)', fontsize = 12)
ax[1,0].set_ylabel('$h$ (m)', fontsize = 12)
ax[2,0].set_ylabel('$h$ (m)', fontsize = 12)

ax[0,0].annotate('$\\kappa = 0.1$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[1,0].annotate('$\\kappa = 0.15$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[2,0].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[0,0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[1,0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[2,0].annotate('$R = 0.0001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)

ax[0,1].annotate('$\\kappa = 0.1$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[1,1].annotate('$\\kappa = 0.15$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[2,1].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[0,1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[1,1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[2,1].annotate('$R = 0.001$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)

ax[0,2].annotate('$\\kappa = 0.1$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[1,2].annotate('$\\kappa = 0.15$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[2,2].annotate('$\\kappa = 0.2$ m$^{-1}$', xy = (0.025, 0.9), xycoords = 'axes fraction', fontsize = 9)
ax[0,2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[1,2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)
ax[2,2].annotate('$R = 0.01$ y$^{-1}$', xy = (0.025, 0.025), xycoords = 'axes fraction', fontsize = 9)

ax[0,0].annotate('(a)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[0,1].annotate('(b)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[0,2].annotate('(c)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)

ax[1,0].annotate('(d)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[1,1].annotate('(e)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[1,2].annotate('(f)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)

ax[2,0].annotate('(g)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[2,1].annotate('(h)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)
ax[2,2].annotate('(i)', xy = (-.1, 1.04), xycoords = 'axes fraction', fontsize = 12)


#plt.legend(['$\\kappa = 0.1$ m$^{-1}$', '$\\kappa = 0.15$ m$^{-1}$', '$\\kappa = 0.2$ m$^{-1}$'], bbox_to_anchor = (0.88, 1.12), ncol = 3)
#ax = plt.gca()
#leg = ax.get_legend()
#leg.legend_handles[0].set_color('gray')
#leg.legend_handles[1].set_color('gray')
#leg.legend_handles[2].set_color('gray')
plt.suptitle('Transects Parallel to Glacier Slope')
plt.savefig('debris-transects-down.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
path = 'output-1a-transects'

with open(path + '/sim_3_z_time=49.pkl', 'rb') as f:
    z = pickle.load(f)
with open(path + '/sim_3_s_time=49.pkl', 'rb') as f:
    s = pickle.load(f)
            
mg = RasterModelGrid((101, 101), xy_spacing=1)

# %%
topo = mg.add_zeros("topographic_surface", at = 'node')
ice = mg.add_zeros("topographic__elevation", at = 'node')

topo += z
ice += s

# %%
h = topo-ice-np.mean(topo-ice)

# %%
fig, ax = plt.subplots(3,3, figsize = (10,8), sharex = True, sharey = True)
sims = [8, 5, 2]
for i in range(3):
    with open(path + '/sim_' + str(sims[i]) + '_z_time=49.pkl', 'rb') as f:
        z = pickle.load(f)
    with open(path + '/sim_' + str(sims[i]) + '_s_time=49.pkl', 'rb') as f:
        s = pickle.load(f)
                
    mg = RasterModelGrid((101, 101), xy_spacing=1)
    
    topo = mg.add_zeros("topographic_surface", at = 'node')
    ice = mg.add_zeros("topographic__elevation", at = 'node')

    topo += z
    ice += s
    h = topo-ice-np.mean(topo-ice)
    plt.sca(ax[i, 0])
    img = imshow_grid(mg, ice-100, cmap = 'bone', shrink = 0.9, colorbar_label = 'm')
    plt.sca(ax[i, 1])
    img = imshow_grid(mg, topo-100, cmap = 'gist_earth', shrink = 0.9, colorbar_label = 'm')
    plt.sca(ax[i, 2])
    img = imshow_grid(mg, h, cmap = 'seismic_r', symmetric_cbar = True, shrink = 0.9, colorbar_label = 'm')
    
for i in range(3):
    for j in range(3):
        ax[i, j].set_xlim([25,75])
        ax[i, j].set_ylim([30,90])
        ax[i, j].set_yticks([30, 50, 70, 90])
        ax[i, j].set_yticklabels([-20, 0, 20, 40])
        ax[i, j].set_xticks([25, 50, 75])
        ax[i, j].set_xticklabels([-25, 0, 25])
        ax[i, j].set_xlabel('X (m)')
        ax[i, j].set_ylabel('Y (m)')
        
ax[0,0].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.0001$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[0,1].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.0001$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[0,2].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.0001$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,0].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.001$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,1].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.001$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,2].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.001$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,0].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,1].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,2].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)

ax[0,0].annotate('(a)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[0,1].annotate('(b)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[0,2].annotate('(c)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[1,0].annotate('(d)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[1,1].annotate('(e)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[1,2].annotate('(f)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[2,0].annotate('(g)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[2,1].annotate('(h)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[2,2].annotate('(i)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[0,0].set_title('Change in\nIce Elevation')
ax[0,1].set_title('Change in\nTopographic Elevation')
ax[0,2].set_title('Debris Thickness\nDeviation from Mean')

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=0.2)
plt.savefig('2d-varying-R.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
fig, ax = plt.subplots(3,3, figsize = (10,8), sharex = True, sharey = True)
sims = [1, 2, 3]
for i in range(3):
    with open(path + '/sim_' + str(sims[i]) + '_z_time=49.pkl', 'rb') as f:
        z = pickle.load(f)
    with open(path + '/sim_' + str(sims[i]) + '_s_time=49.pkl', 'rb') as f:
        s = pickle.load(f)
                
    mg = RasterModelGrid((101, 101), xy_spacing=1)
    
    topo = mg.add_zeros("topographic_surface", at = 'node')
    ice = mg.add_zeros("topographic__elevation", at = 'node')

    topo += z
    ice += s
    h = topo-ice-np.mean(topo-ice)
    plt.sca(ax[i, 0])
    img = imshow_grid(mg, ice-100, cmap = 'bone', shrink = 0.9, colorbar_label = 'm')
    plt.sca(ax[i, 1])
    img = imshow_grid(mg, topo-100, cmap = 'gist_earth', shrink = 0.9, colorbar_label = 'm')
    plt.sca(ax[i, 2])
    img = imshow_grid(mg, h, cmap = 'seismic_r', symmetric_cbar = True, shrink = 0.9, colorbar_label = 'm')
    
for i in range(3):
    for j in range(3):
        ax[i, j].set_xlim([25,75])
        ax[i, j].set_ylim([30,90])
        ax[i, j].set_yticks([30, 50, 70, 90])
        ax[i, j].set_yticklabels([-20, 0, 20, 40])
        ax[i, j].set_xticks([25, 50, 75])
        ax[i, j].set_xticklabels([-25, 0, 25])
        ax[i, j].set_xlabel('X (m)')
        ax[i, j].set_ylabel('Y (m)')

ax[0,0].annotate("$\\kappa = 0.1$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[0,1].annotate("$\\kappa = 0.1$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[0,2].annotate("$\\kappa = 0.1$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,0].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,1].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,2].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,0].annotate("$\\kappa = 0.2$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,1].annotate("$\\kappa = 0.2$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,2].annotate("$\\kappa = 0.2$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)

ax[0,0].annotate('(a)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[0,1].annotate('(b)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[0,2].annotate('(c)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[1,0].annotate('(d)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[1,1].annotate('(e)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[1,2].annotate('(f)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[2,0].annotate('(g)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[2,1].annotate('(h)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[2,2].annotate('(i)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[0,0].set_title('Change in\nIce Elevation')
ax[0,1].set_title('Change in\nTopographic Elevation')
ax[0,2].set_title('Debris Thickness\nDeviation from Mean')
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=0.2)
plt.savefig('2d-varying-k.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
fig, ax = plt.subplots(3,3, figsize = (10,8), sharex = True, sharey = True)
years = [1, 25, 49]
for i in range(3):
    with open(path + '/sim_2_z_time=' + str(years[i]) + '.pkl', 'rb') as f:
        z = pickle.load(f)
    with open(path + '/sim_2_s_time=' + str(years[i]) + '.pkl', 'rb') as f:
        s = pickle.load(f)
                
    mg = RasterModelGrid((101, 101), xy_spacing=1)
    
    topo = mg.add_zeros("topographic_surface", at = 'node')
    ice = mg.add_zeros("topographic__elevation", at = 'node')

    topo += z
    ice += s
    h = topo-ice-np.mean(topo-ice)
    plt.sca(ax[i, 0])
    img = imshow_grid(mg, ice-100, cmap = 'bone', shrink = 0.9, colorbar_label = 'm')
    plt.sca(ax[i, 1])
    img = imshow_grid(mg, topo-100, cmap = 'gist_earth', shrink = 0.9, colorbar_label = 'm')
    plt.sca(ax[i, 2])
    img = imshow_grid(mg, h, cmap = 'seismic_r', symmetric_cbar = True, shrink = 0.9, colorbar_label = 'm')
    
for i in range(3):
    for j in range(3):
        ax[i, j].set_xlim([25,75])
        ax[i, j].set_ylim([30,90])
        ax[i, j].set_yticks([30, 50, 70, 90])
        ax[i, j].set_yticklabels([-20, 0, 20, 40])
        ax[i, j].set_xticks([25, 50, 75])
        ax[i, j].set_xticklabels([-25, 0, 25])
        ax[i, j].set_xlabel('X (m)')
        ax[i, j].set_ylabel('Y (m)')

ax[0,0].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 1 year", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[0,1].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 1 year", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[0,2].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 1 year", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,0].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 25 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,1].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 25 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[1,2].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 25 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,0].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,1].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)
ax[2,2].annotate("$\\kappa = 0.15$ m$^{-1}$\n$R = 0.01$ y$^{-1}$\nt = 50 years", xy = (0.05, 0.75), xycoords = 'axes fraction', fontsize = 8)

ax[0,0].annotate('(a)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[0,1].annotate('(b)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[0,2].annotate('(c)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[1,0].annotate('(d)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[1,1].annotate('(e)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[1,2].annotate('(f)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[2,0].annotate('(g)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[2,1].annotate('(h)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)
ax[2,2].annotate('(i)', xy = (-.27, 1.06), xycoords = 'axes fraction', fontsize = 12)

ax[0,0].set_title('Change in\nIce Elevation')
ax[0,1].set_title('Change in\nTopographic Elevation')
ax[0,2].set_title('Debris Thickness\nDeviation from Mean')
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.3, hspace=0.2)
plt.savefig('2d-time-development.png', dpi = 300, bbox_inches = 'tight')
plt.show()

# %%
imshow_grid(mg, topo, cmap = 'bone')

# %%
path = 'output-1a-transects'
for y in range(1, 50):
    with open(path + '/sim_3_z_time=' + str(y) + '.pkl', 'rb') as f:
        z = pickle.load(f)
        
    mg = RasterModelGrid((101, 101), xy_spacing=1)
    topo = mg.add_zeros("topographic_surface", at = 'node')
    topo += z
    


    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

    # Make data.
    X = np.arange(-30,30,1)
    Y = np.arange(-20,60, 1)
    X, Y = np.meshgrid(X, Y)
    Z = mg.node_vector_to_raster(topo)[20:100,20:80]


    # Plot the surface.

    ls = LightSource(270, 45)
    # To use a custom hillshading mode, override the built-in shading and pass
    # in the rgb colors of the shaded surface calculated from "shade".
    rgb = ls.shade(Z, cmap=cm.gist_earth, vert_exag=0.2, blend_mode='overlay')
    surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, facecolors=rgb, linewidth=0, antialiased=False, shade=False)
    ax.set_zlim([Z[20,0]-5, Z[20,0]+7])
    ax.view_init(azim=-20, elev=40)
    ax.set_axis_off()
    # Customize the z axis.
    #ax.set_zlim(-1.01, 1.01)
    #ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    #ax.zaxis.set_major_formatter('{x:.02f}')
    plt.savefig('3d-animations/3d-depression_y' + str(y) + '.png', dpi = 300, bbox_inches = 'tight')
    #plt.show()
# Out:
# C:\Users\edwar\AppData\Local\Temp\ipykernel_15172\2196960440.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
